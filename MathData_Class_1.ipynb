# %% [markdown]
# <a href="https://colab.research.google.com/github/nataliarigol/MathData24/blob/main/MathData_Class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Notes
#
#
# <img src="https://www.flbog.edu/wp-content/uploads/fau-masthead-1024x427-1.jpg" width=400>
#
#
# <img src="https://cdn.sanity.io/images/oaglaatp/production/86a82e4fb0cc58a2d321c9a4a78533904964cd51-6119x3718.jpg" width = 400>

# %%
apples = 10

# %%
oranges = 8

# %%
total = apples + oranges

# %%
total
# Out:
# 18

# %%
print(total)
# Out:
# 18

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.random.random()

# %%
A
# Out:
# 0.22733122010428908

# %%
A = np.random.random((1,5))

# %%
A
# Out:
# array([[0.89471437, 0.64931952, 0.45977272, 0.40524308, 0.27428931]])

# %%
B = np.random.random((1,5))

# %%
A,B
# Out:
# (array([[0.89471437, 0.64931952, 0.45977272, 0.40524308, 0.27428931]]),
#  array([[0.68841129, 0.82643125, 0.13572214, 0.98203286, 0.67767974]]))

# %%
A = A.T
B = B.T

# %%
A,B
# Out:
# (array([[0.89471437],
#         [0.64931952],
#         [0.45977272],
#         [0.40524308],
#         [0.27428931]]),
#  array([[0.68841129],
#         [0.82643125],
#         [0.13572214],
#         [0.98203286],
#         [0.67767974]]))

# %%
plt.plot(A,B)

# %%
plt.plot(A,B,'r.')

# %%
X = np.random.random((100,1))
Y = np.random.random((100,1))
plt.plot(X,Y,'g--')

# %%
print(A.shape,B.shape,X.shape,Y.shape)
# Out:
# (5, 1) (5, 1) (100, 1) (100, 1)

# %%
Z = np.random.random((100,100))

# %%
Z.shape
# Out:
# (100, 100)

# %%
Z
# Out:
# array([[0.49266577, 0.44183875, 0.24355863, ..., 0.98997855, 0.53936185,
#         0.2009871 ],
#        [0.77043337, 0.36647935, 0.11998051, ..., 0.36639371, 0.2772106 ,
#         0.14922518],
#        [0.75315566, 0.17009546, 0.1103338 , ..., 0.54003012, 0.70569117,
#         0.99813141],
#        ...,
#        [0.80459291, 0.46532527, 0.29178585, ..., 0.03590407, 0.23057228,
#         0.73818288],
#        [0.02570613, 0.80568587, 0.30529839, ..., 0.56369023, 0.68228854,
#         0.86541319],
#        [0.03290495, 0.16605188, 0.02062215, ..., 0.17649228, 0.41921621,
#         0.86892248]])

# %%
plt.imshow(Z)

# %%
# Create a sample matrix (2D array)
matrix = np.array([[1, 2, 3, 4],
                   [15, 16, 27, 8],
                   [9, 10, 11, 12],
                   [13, 14, 15, 16]])

# Plot the matrix
plt.imshow(matrix, cmap='Blues')
